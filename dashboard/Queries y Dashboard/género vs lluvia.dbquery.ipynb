-- %%
SELECT
  lluvia,
  viajes_hombres,
  viajes_mujeres,
  viajes_otros
FROM catalog_ecobici.golden.ecobici_vs_lluvia
ORDER BY lluvia;
-- Out:
-- Databricks visualization. Run in Databricks to view.
